# %% [markdown]
# # Plotting
#
# ## Simple interface

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 20, 1000)  # 100 evenly-spaced values from 0 to 50
y = np.sin(x)

plt.plot(x, y);

# %%
plt.plot(x, y)
plt.xlim(5, 15)
plt.ylim(-1.2, 1.2)
plt.xlabel('this is x!')
plt.ylabel('this is y!')
plt.title('My First Plot');

# %%
plt.plot(x, y, '--r');

# %%
plt.plot(x, y, label='test')
plt.legend()

# %% [markdown]
# ## Exercise: simple interface
#
# Below are two sets of arrays x1, y1, and x2, y2. Create a plot where x1 and y1
# are represented by blue circles, and x2 and y2 are represented by a dotted black
# line. Label the symbols "sampled" and "continuous", and add a legend. Adjust the
# y limits to suit your taste.

# %%
x1 = np.linspace(0, 10, 20)
y1 = np.sin(x1)

x2 = np.linspace(0, 10, 1000)
y2 = np.sin(x2) * 2

plt.plot(x1, y1, 'ob', label='sampled')
plt.plot(x2, y2, '--k', label='continous')
plt.legend();

# %% [markdown]
# ## Object-oriented interface
#
#
# When we called `pylab.plot` previously, there were a few things happening in the background:
#  - matplotlib created a `Figure` instance, which is an object describing the plot window and its properties, and containing lists of all its elements
#  - matplotlib created an `Axes` element within the figure. An axes can be thought of as a plotting window, where data can be arranged by `x` and `y` coordinates.
#
# We're going to repeat some of the previous examples now, except we will specify these `Figure` and `Axes` instances explicitly:

# %%
fig, ax = plt.subplots()
ax.plot(x, y, label='Mike')
ax.set_ylim(0, 5)
ax.legend()

# %%
import pandas as pd

df = pd.DataFrame(zip(x, y), columns=['x', 'y'])
df.head()
# Out:
#          x         y
# 0  0.00000  0.000000
# 1  0.02002  0.020019
# 2  0.04004  0.040029
# 3  0.06006  0.060024
# 4  0.08008  0.079995

# %%
fig, ax = plt.subplots()
ax.set_ylim(-1, 5)

df.plot(ax=ax);

# %%
fig, ax = plt.subplots(2, 1, sharey=True)
df[['x']].plot(ax = ax[0])
df[['y']].plot(ax = ax[1])

# %% [markdown]
# ## Exercise: object-oriented interface
#
# Repeat the exercise, but use the object-oriented interface.
#
# Below are two sets of arrays x1, y1, and x2, y2. Create a plot where x1 and y1
# are represented by blue circles, and x2 and y2 are represented by a dotted black
# line. Label the symbols "sampled" and "continuous", and add a legend. Adjust the
# y limits to suit your taste.
